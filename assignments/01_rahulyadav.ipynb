# %%
import pandas as pd

# %%
from IPython.display import Image
Image('/Users/rahulgarg/github/AnalyticsCourse/assignments/WhatsApp Image 2021-06-05 at 6.01.35 PM.jpeg')

# %%
df = pd.read_csv('/Users/rahulgarg/github/AnalyticsCourse/assignments/Train.csv')

# %%
df
# Out:
#        EmpID  EmpName LanguageOfCommunication  Age  Gender  \
# 0      11041     John                 English   35    Male
# 1      15079  William                 English   26    Male
# 2      18638    James                 English   36  Female
# 3       3941  Charles                 English   29  Female
# 4       5936   George                 English   25    Male
# ...      ...      ...                     ...  ...     ...
# 13640  19504   Perley                 English   25  Female
# 13641  17071  Randall                  Native   29   Other
# 13642   6659  Raphael                   Hindi   37    Male
# 13643   5986     Reed                   Hindi   24    Male
# 13644   4668   Shelby                 English   35    Male
#
#       JobProfileIDApplyingFor HighestDegree             DegreeBranch  \
# 0                     JR85289        B.Tech               Electrical
# 1                     JR87525        B.Tech  Artificial Intelligence
# ...

# %%
df.loc[0]
# Out:
# EmpID                                 11041
# EmpName                                John
# LanguageOfCommunication             English
# Age                                      35
# Gender                                 Male
# JobProfileIDApplyingFor             JR85289
# HighestDegree                        B.Tech
# DegreeBranch                     Electrical
# GraduatingInstitute                  Tier 1
# LatestDegreeCGPA                          7
# YearsOfExperince                         12
# GraduationYear                         2009
# CurrentCTC                               21
# ExpectedCTC                              26
# MartialStatus                       Married
# EmpScore                                  5
# CurrentDesignation                      SSE
# CurrentCompanyType               Enterprise
# DepartmentInCompany                  Design
# TotalLeavesTaken                         20
# BiasInfluentialFactor      YearsOfExperince
# ...

# %%
df.Gender.value_counts()
# Out:
# Male      8376
# Female    4326
# Other      943
# Name: Gender, dtype: int64

# %%
df.head(2)
# Out:
#    EmpID  EmpName LanguageOfCommunication  Age Gender JobProfileIDApplyingFor  \
# 0  11041     John                 English   35   Male                 JR85289
# 1  15079  William                 English   26   Male                 JR87525
#
#   HighestDegree             DegreeBranch GraduatingInstitute  \
# 0        B.Tech               Electrical              Tier 1
# 1        B.Tech  Artificial Intelligence              Tier 3
#
#    LatestDegreeCGPA  ...  CurrentCTC  ExpectedCTC  MartialStatus  EmpScore  \
# 0                 7  ...          21           26        Married         5
# 1                 7  ...          15           19        Married         5
#
#   CurrentDesignation  CurrentCompanyType DepartmentInCompany TotalLeavesTaken  \
# 0                SSE          Enterprise              Design               20
# 1                 BA            MidSized         Engineering                6
#
#   BiasInfluentialFactor  FitmentPercent
# ...

# %%
df.columns
# Out:
# Index(['EmpID', 'EmpName', 'LanguageOfCommunication', 'Age', 'Gender',
#        'JobProfileIDApplyingFor', 'HighestDegree', 'DegreeBranch',
#        'GraduatingInstitute', 'LatestDegreeCGPA', 'YearsOfExperince',
#        'GraduationYear', 'CurrentCTC', 'ExpectedCTC', 'MartialStatus',
#        'EmpScore', 'CurrentDesignation', 'CurrentCompanyType',
#        'DepartmentInCompany', 'TotalLeavesTaken', 'BiasInfluentialFactor',
#        'FitmentPercent'],
#       dtype='object')

# %%
features = ['LanguageOfCommunication','Age','Gender','JobProfileIDApplyingFor','HighestDegree','DegreeBranch','GraduatingInstitute',
           'LatestDegreeCGPA','YearsOfExperince','GraduationYear', 'CurrentCTC', 'ExpectedCTC', 'MartialStatus',
           'EmpScore', 'CurrentDesignation', 'CurrentCompanyType',
           'DepartmentInCompany', 'TotalLeavesTaken']

# %%
X = df.loc[:, features]
y = df.FitmentPercent

# %%
X_object = X.select_dtypes(include = 'object')

# %%
X_others = X.select_dtypes(exclude = 'object')

# %%
X_others
# Out:
#        Age  LatestDegreeCGPA  YearsOfExperince  GraduationYear  CurrentCTC  \
# 0       35                 7                12            2009          21
# 1       26                 7                 3            2018          15
# 2       36                 6                 6            2015          15
# 3       29                 5                 6            2015          16
# 4       25                 8                 2            2019          24
# ...    ...               ...               ...             ...         ...
# 13640   25                 7                 2            2019          30
# 13641   29                 7                 6            2015          22
# 13642   37                 8                11            2010           8
# 13643   24                 4                 1            2020          27
# 13644   35                 7                12            2009          17
#
#        ExpectedCTC  EmpScore  TotalLeavesTaken
# ...

# %%
X.dtypes
# Out:
# LanguageOfCommunication    object
# Age                         int64
# Gender                     object
# JobProfileIDApplyingFor    object
# HighestDegree              object
# DegreeBranch               object
# GraduatingInstitute        object
# LatestDegreeCGPA            int64
# YearsOfExperince            int64
# GraduationYear              int64
# CurrentCTC                  int64
# ExpectedCTC                 int64
# MartialStatus              object
# EmpScore                    int64
# CurrentDesignation         object
# CurrentCompanyType         object
# DepartmentInCompany        object
# TotalLeavesTaken            int64
# dtype: object

# %%
X_object = X_object.apply(preprocessing.LabelEncoder().fit_transform)

# %%
X = pd.concat([X_object, X_others], axis =1 )

# %%
X
# Out:
#        LanguageOfCommunication  Gender  JobProfileIDApplyingFor  \
# 0                            0       1                        3
# 1                            0       1                        4
# 2                            0       0                        4
# 3                            0       0                        4
# 4                            0       1                        0
# ...                        ...     ...                      ...
# 13640                        0       0                        4
# 13641                        2       2                        4
# 13642                        1       1                        6
# 13643                        1       1                        4
# 13644                        0       1                        4
#
#        HighestDegree  DegreeBranch  GraduatingInstitute  MartialStatus  \
# 0                  0             2                    0              0
# ...

# %%
y
# Out:
# 0        95.40
# 1        67.09
# 2        91.26
# 3        72.29
# 4        86.34
#          ...
# 13640    93.65
# 13641    52.90
# 13642    61.46
# 13643    93.64
# 13644    93.52
# Name: FitmentPercent, Length: 13645, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

rf_regr = RandomForestRegressor(max_depth=4, random_state=0)
rf_regr.fit(X, y) # Fit
print("%.4f" % rf_regr.score(X,y))
# Out:
# 0.6147

# %%
pd.concat((pd.DataFrame(X.columns, columns = ['variable']), 
           pd.DataFrame(rf_regr.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)
# Out:
#                    variable  importance
# 1                    Gender    0.423008
# 8        CurrentCompanyType    0.279845
# 16                 EmpScore    0.166699
# 14               CurrentCTC    0.124988
# 15              ExpectedCTC    0.000853
# 17         TotalLeavesTaken    0.000843
# 10                      Age    0.000624
# 9       DepartmentInCompany    0.000487
# 2   JobProfileIDApplyingFor    0.000400
# 11         LatestDegreeCGPA    0.000316
# 7        CurrentDesignation    0.000312
# 3             HighestDegree    0.000310
# 5       GraduatingInstitute    0.000279
# 4              DegreeBranch    0.000274
# 0   LanguageOfCommunication    0.000265
# 13           GraduationYear    0.000226
# 12         YearsOfExperince    0.000178
# 6             MartialStatus    0.000092
